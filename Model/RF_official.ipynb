# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
X_train = pd.read_csv('/content/drive/MyDrive/DS560/Data/Clean_data/X_train.csv',index_col=0)
X_test = pd.read_csv('/content/drive/MyDrive/DS560/Data/Clean_data/X_test.csv',index_col=0)
X_train.head()
# Out:
#       Ozone      PM2.5  Conductance        PH  oil_count  Gas_Well_Number  \
# 0  0.024906  13.048837   484.000000  8.100000   6.876457          1.71246
# 1  0.032330  11.807599   487.333333  8.266667   6.876457          1.71246
# 2  0.043829   9.498854   518.333333  8.233333   6.876457          1.71246
# 3  0.046979  10.973611   497.666667  8.433333   6.876457          1.71246
# 4  0.046677  11.404237   498.000000  8.500000   6.876457          1.71246
#
#    positive_tests  fire  enc_county
# 0               0     0           0
# 1               0     0           0
# 2               0     0           0
# 3               0     0           0
# 4               0     0           0

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline

pipeline = Pipeline([
    ('std_scalar', StandardScaler())
])

X_train = pipeline.fit_transform(X_train)
X_test = pipeline.transform(X_test)

# %%
X_train
# Out:
# array([[-1.45518774,  0.76967414, -1.32832566, ..., -0.09866227,
#         -0.46418705, -1.5666989 ],
#        [-0.78536955,  0.46749086, -1.32463571, ..., -0.09866227,
#         -0.46418705, -1.5666989 ],
#        [ 0.25209504, -0.09458013, -1.29031923, ..., -0.09866227,
#         -0.46418705, -1.5666989 ],
#        ...,
#        [-0.07835558, -0.05628825,  0.72716818, ..., -0.06426389,
#         -0.46418705,  1.5666989 ],
#        [-0.93242605, -0.6529389 ,  0.72716818, ...,  0.02522175,
#         -0.46418705,  1.5666989 ],
#        [-1.11068579, -0.05542714,  0.72716818, ...,  0.21565915,
#         -0.46418705,  1.5666989 ]])

# %%
X_train=pd.DataFrame(X_train)
X_train.columns = ['Ozone','PM2.5','Conductance','PH','oil_count','Gas_Well_Number','positive_tests','fire','enc_county']
# X_train=X_train[X_train['enc_county']==0]
X_train = X_train.drop(['enc_county', 'Gas_Well_Number'],axis=1)
X_train = X_train[71:131]
X_train
# Out:
#         Ozone     PM2.5  Conductance        PH  oil_count  positive_tests  \
# 71  -1.064900  0.163340     0.735737 -0.031776  -1.553951       -0.098662
# 72  -1.080085  0.404201     0.735737 -0.031776  -1.553951       -0.098662
# 73   0.109662  0.164015     0.735737 -0.031776  -1.553951       -0.098662
# 74   0.405478  0.327541     0.735737 -0.031776  -1.553951       -0.098662
# 75   0.803067 -0.085352     0.735737 -0.031776  -1.553951       -0.098662
# 76   0.457269 -0.091768     0.735737 -0.031776  -1.553951       -0.098662
# 77   1.525349  1.003330     0.735737 -0.031776  -1.553951       -0.098662
# 78   1.515355  0.797942     0.735737 -0.031776  -1.553951       -0.098662
# 79   1.373703  0.586648     0.735737 -0.031776  -1.553951       -0.098662
# 80   0.853782  0.380463     0.735737 -0.031776  -1.553951       -0.098662
# 81  -0.052656 -0.111621     0.735737 -0.031776  -1.553951       -0.098662
# 82  -0.326417  0.379672     0.735737 -0.031776  -1.553951       -0.098662
# ...

# %%
y_train = pd.read_csv('/content/drive/MyDrive/DS560/Data/Clean_data/y_train.csv',index_col=0)
y_train = y_train[71:131]
y_train
# Out:
#         Price
# 71   5.701352
# 72   5.682100
# 73   5.647784
# 74   5.645127
# 75   5.660087
# 76   5.669586
# 77   5.700868
# 78   5.710710
# 79   5.716337
# 80   5.740919
# 81   5.729780
# 82   5.687582
# 83   5.718103
# 84   5.706829
# 85   5.672283
# 86   5.668209
# 87   5.681449
# 88   5.692000
# 89   5.738955
# 90   5.753001
# 91   5.756423
# 92   5.782551
# 93   5.763697
# 94   5.725029
# 95   5.761695
# 96   5.751356
# 97   5.722041
# 98   5.723439
# 99   5.723078
# 100  5.729926
# 101  5.767964
# 102  5.776352
# 103  5.783539
# 104  5.802555
# 105  5.788522
# 106  5.743463
# 107  5.769481
# 108  5.752824
# 109  5.733510
# 110  5.720589
# 111  5.735735
# 112  5.731975
# 113  5.777920
# 114  5.786205
# 115  5.797745
# 116  5.821586
# 117  5.811508
# 118  5.774400
# 119  5.807088
# 120  5.790651
# 121  5.763944
# 122  5.754280
# 123  5.752179
# 124  5.743282
# 125  5.791915
# 126  5.819768
# 127  5.840501
# 128  5.884234
# 129  5.872203
# 130  5.828215

# %%
X_test=pd.DataFrame(X_test)
X_test.columns = ['Ozone','PM2.5','Conductance','PH','oil_count','Gas_Well_Number','positive_tests','fire','enc_county']
# X_test = X_test[X_test['enc_county']==0]
X_test = X_test.drop(['enc_county','Gas_Well_Number'],axis=1)
X_test
# Out:
#         Ozone     PM2.5  Conductance        PH  oil_count  positive_tests  \
# 0   -0.818945  0.681985     0.735737 -0.031776  -1.553951       24.168086
# 1   -0.134532  0.315105     0.735737 -0.031776  -1.553951        4.786655
# 2    0.358334 -0.309280    -1.297884  0.159494  -1.553951        1.463473
# 3    0.931605  0.477501    -1.308953  0.998453  -1.553951        0.956408
# 4    0.927739  0.456702    -1.299729  1.155758  -0.922441        0.441554
# ..        ...       ...          ...       ...        ...             ...
# 115 -0.969387 -0.866676     0.727168 -0.136808   0.617325        0.039430
# 116 -0.523435 -0.681527     0.727168 -0.136808   0.617325       -0.018836
# 117 -0.384420 -1.676746     0.727168 -0.136808   0.617325       -0.042079
# 118 -1.064747 -0.712168     0.727168 -0.136808   0.617325       -0.017527
# 119 -0.871140 -1.119509     0.727168 -0.136808   0.617325        0.100188
#
#          fire
# 0   -0.464187
# 1   -0.464187
# 2   -0.464187
# 3   -0.464187
# ...

# %%
y_test = pd.read_csv('/content/drive/MyDrive/DS560/Data/Clean_data/y_test.csv',index_col=0)
y_test = y_test[0:12]
y_test
# Out:
#         Price
# 132  5.843644
# 133  5.822247
# 134  5.824919
# 135  5.856391
# 136  5.860745
# 137  5.900979
# 138  5.908351
# 139  5.919115
# 140  5.947458
# 141  5.928892
# 142  5.880814
# 143  5.886491

# %%
# frames = [X_train.iloc[125:131], X_test.iloc[0:12]]
# X_test = pd.concat(frames)

# %%
# X_test = X_test.tail(6)
X_test = X_test[0:12]
X_test
# Out:
#        Ozone     PM2.5  Conductance        PH  oil_count  positive_tests  \
# 0  -0.818945  0.681985     0.735737 -0.031776  -1.553951       24.168086
# 1  -0.134532  0.315105     0.735737 -0.031776  -1.553951        4.786655
# 2   0.358334 -0.309280    -1.297884  0.159494  -1.553951        1.463473
# 3   0.931605  0.477501    -1.308953  0.998453  -1.553951        0.956408
# 4   0.927739  0.456702    -1.299729  1.155758  -0.922441        0.441554
# 5   1.014978  0.075340    -1.273161  1.260628  -1.553951        0.478757
# 6   1.160754  0.673630    -1.267442  2.256892  -1.553951        4.156766
# 7   1.383490  0.727460    -1.258586  1.784977  -1.553951        7.143381
# 8   1.202004  0.768709    -1.313566  0.002190  -1.553951        3.599475
# 9   0.395652  0.443243    -1.255080 -0.050245  -1.553951        2.383879
# 10 -0.403176  1.969721    -1.315780 -0.627030  -1.553951        2.529075
# 11 -0.997469  1.555140    -1.423748  0.107060  -1.553951       18.507246
#
#         fire
# ...

# %%
# frames = [y_train, y_test.iloc[0:6]]
# y_train = pd.concat(frames)
y_train
# Out:
#         Price
# 71   5.701352
# 72   5.682100
# 73   5.647784
# 74   5.645127
# 75   5.660087
# 76   5.669586
# 77   5.700868
# 78   5.710710
# 79   5.716337
# 80   5.740919
# 81   5.729780
# 82   5.687582
# 83   5.718103
# 84   5.706829
# 85   5.672283
# 86   5.668209
# 87   5.681449
# 88   5.692000
# 89   5.738955
# 90   5.753001
# 91   5.756423
# 92   5.782551
# 93   5.763697
# 94   5.725029
# 95   5.761695
# 96   5.751356
# 97   5.722041
# 98   5.723439
# 99   5.723078
# 100  5.729926
# 101  5.767964
# 102  5.776352
# 103  5.783539
# 104  5.802555
# 105  5.788522
# 106  5.743463
# 107  5.769481
# 108  5.752824
# 109  5.733510
# 110  5.720589
# 111  5.735735
# 112  5.731975
# 113  5.777920
# 114  5.786205
# 115  5.797745
# 116  5.821586
# 117  5.811508
# 118  5.774400
# 119  5.807088
# 120  5.790651
# 121  5.763944
# 122  5.754280
# 123  5.752179
# 124  5.743282
# 125  5.791915
# 126  5.819768
# 127  5.840501
# 128  5.884234
# 129  5.872203
# 130  5.828215

# %%
# y_test = y_test[6::]
# frames = [y_train.iloc[125:131], y_test]
# y_test = pd.concat(frames)
y_test
# Out:
#         Price
# 132  5.843644
# 133  5.822247
# 134  5.824919
# 135  5.856391
# 136  5.860745
# 137  5.900979
# 138  5.908351
# 139  5.919115
# 140  5.947458
# 141  5.928892
# 142  5.880814
# 143  5.886491

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import accuracy_score
#import hvplot.pandas
# %matplotlib inline

# %%
from sklearn import metrics
from sklearn.model_selection import cross_val_score

def cross_val(model):
    pred = cross_val_score(model, X_train, y_train, cv=10)
    return pred.mean()

def print_evaluate(true, predicted):  
    mae = metrics.mean_absolute_error(true, predicted)
    mse = metrics.mean_squared_error(true, predicted)
    rmse = np.sqrt(metrics.mean_squared_error(true, predicted))
    r2_square = metrics.r2_score(true, predicted)
    print('MAE:', mae)
    print('MSE:', mse)
    print('RMSE:', rmse)
    print('R2 Square', r2_square)
    print('__________________________________')
    
def evaluate(true, predicted):
    mae = metrics.mean_absolute_error(true, predicted)
    mse = metrics.mean_squared_error(true, predicted)
    rmse = np.sqrt(metrics.mean_squared_error(true, predicted))
    r2_square = metrics.r2_score(true, predicted)
    return mae, mse, rmse, r2_square

# %%
from sklearn.ensemble import RandomForestRegressor

rf_reg = RandomForestRegressor(n_estimators=1000, max_depth=10)
rf_reg.fit(X_train, y_train)

test_pred = rf_reg.predict(X_test)
train_pred = rf_reg.predict(X_train)

print('Test set evaluation:\n_____________________________________')
print_evaluate(y_test['Price'], test_pred)

print('Train set evaluation:\n_____________________________________')
print_evaluate(y_train, train_pred)

results_df_2 = pd.DataFrame(data=[["Random Forest Regressor", *evaluate(y_test, test_pred), 0]], 
                            columns=['Model', 'MAE', 'MSE', 'RMSE', 'R2 Square', 'Cross Validation'])
# results_df = results_df.append(results_df_2, ignore_index=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   after removing the cwd from sys.path.
# Test set evaluation:
# _____________________________________
# MAE: 0.11851368043870059
# MSE: 0.0152180584422274
# RMSE: 0.12336149497402907
# R2 Square -8.955404475398318
# __________________________________
# Train set evaluation:
# _____________________________________
# MAE: 0.011462320597624769
# MSE: 0.00021929620339920447
# RMSE: 0.014808652990707983
# R2 Square 0.9188410678954526
# __________________________________

# %%
import matplotlib.pyplot as plot
plot.scatter([i for i in range(len(X_train))], y_train, color = 'red')
plot.plot([i for i in range(len(X_train))], train_pred, color = 'blue')
plot.title('RF Training Data')
plot.xlabel('Months from 2017 to 2021')
plot.ylabel('House Price')
plot.show()

# %%
import matplotlib.pyplot as plot
plot.scatter([i for i in range(len(X_test))], y_test, color = 'red')
plot.plot([i for i in range(len(X_test))], test_pred, color = 'blue')
plot.title('RF Testing Data')
plot.xlabel('Months from 2021-7 to 2021-12')
plot.ylabel('House Price')
plot.show()
